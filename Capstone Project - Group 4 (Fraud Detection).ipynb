# %% [markdown]
# # 1. Importing of Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_details=pd.read_csv('Capstone_Dataset.csv')
df_details.head()
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          v8        v9  ...       v21       v22       v23       v24       v25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# # 2. Data Preparation

# %%
df_details.shape
# Out:
# (284807, 31)

# %%
df_details.info()
#No missing values in the rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# time      284807 non-null int64
# v1        284807 non-null float64
# v2        284807 non-null float64
# v3        284807 non-null float64
# v4        284807 non-null float64
# v5        284807 non-null float64
# v6        284807 non-null float64
# v7        284807 non-null float64
# v8        284807 non-null float64
# v9        284807 non-null float64
# v10       284807 non-null float64
# v11       284807 non-null float64
# v12       284807 non-null float64
# v13       284807 non-null float64
# v14       284807 non-null float64
# v15       284807 non-null float64
# v16       284807 non-null float64
# v17       284807 non-null float64
# v18       284807 non-null float64
# v19       284807 non-null float64
# v20       284807 non-null float64
# v21       284807 non-null float64
# v22       284807 non-null float64
# v23       284807 non-null float64
# ...

# %%
df_details.dtypes
# Out:
# time        int64
# v1        float64
# v2        float64
# v3        float64
# v4        float64
# v5        float64
# v6        float64
# v7        float64
# v8        float64
# v9        float64
# v10       float64
# v11       float64
# v12       float64
# v13       float64
# v14       float64
# v15       float64
# v16       float64
# v17       float64
# v18       float64
# v19       float64
# v20       float64
# v21       float64
# v22       float64
# v23       float64
# v24       float64
# v25       float64
# v26       float64
# v27       float64
# v28       float64
# amount    float64
# class        bool
# dtype: object

# %% [markdown]
# <b>From the above outpuut it can be denoted that there are no missing values present in the columns. Please find the proof of the missing values below</b>

# %% [markdown]
# <b>PERCENTAGE OF MISSING VALUES</b>

# %%
(df_details.isnull().sum()/len(df_details))*100
# Out:
# time      0.0
# v1        0.0
# v2        0.0
# v3        0.0
# v4        0.0
# v5        0.0
# v6        0.0
# v7        0.0
# v8        0.0
# v9        0.0
# v10       0.0
# v11       0.0
# v12       0.0
# v13       0.0
# v14       0.0
# v15       0.0
# v16       0.0
# v17       0.0
# v18       0.0
# v19       0.0
# v20       0.0
# v21       0.0
# v22       0.0
# v23       0.0
# v24       0.0
# v25       0.0
# v26       0.0
# v27       0.0
# v28       0.0
# amount    0.0
# class     0.0
# dtype: float64

# %% [markdown]
# # Univariate Analysis for each feature

# %%
#1) For V1
plt.subplots(2,0,figsize=(15,5))
plt.title("Distribution of v1 feature")
sns.boxplot(df_details['v1'])
plt.xlabel('Feature v1')

plt.subplots(1,0,figsize=(15,5))
plt.title("Distribution of v1 feature")
sns.kdeplot(df_details['v1'])
plt.xlabel('Feature v1')
# display the plot
plt.show()

# %% [markdown]
# <b>Inference</b> -
#
# 1)The data is a PCA data which means that it is already transformed and Scaled
# 2)From the above graph it can be observed that the maximum data points lies less than -10 due to which it i negatively skewed or left skewed
# 3)It is also observed that the graph have 3 peak which indicates that it is trimodal

# %%
#2) For v2
plt.subplots(2,0,figsize=(15,5))
plt.title("Distribution of v2 feature")
sns.boxplot(df_details['v2'])
plt.xlabel('Feature v2')

plt.subplots(1,0,figsize=(15,5))
plt.title("Distribution of v2 feature")
sns.kdeplot(df_details['v2'])
plt.xlabel('Feature v2')
# display the plot
plt.show()

# %% [markdown]
# <b>Inference</b> -
#
# 1) The observed data for v2 feature is a PCA Data (already transformed data and scaled)
# 2) From the graph it can be observed that maximum data points lies below -20 which indicates that it is negatively skewed or left skewed
# 3) The graph contains only one peek hence it is a unimodal graph

# %%
#3) For v3
plt.subplots(2,0,figsize=(15,5))
plt.title("Distribution of v3 feature")
sns.boxplot(df_details['v3'])
plt.xlabel('Feature v3')

plt.subplots(1,0,figsize=(15,5))
plt.title("Distribution of v3 feature")
sns.kdeplot(df_details['v3'])
plt.xlabel('Feature v3')
# display the plot
plt.show()

# %% [markdown]
# <b>Inference</b> -
#
# 1) The data is a PCA data which means that it is already transformed and Scaled
# 2) From the above graph it can be observed that the maximum data points lies less than -10 hence it is left or negatively skewed
# 3) It is also observed that the graph have 3 peak which indicates that it is trimodal

# %%
#4) For v4
plt.subplots(2,0,figsize=(15,5))
plt.title("Distribution of v4 feature")
sns.boxplot(df_details['v4'])
plt.xlabel('Feature v4')

plt.subplots(1,0,figsize=(15,5))
plt.title("Distribution of v4 feature")
sns.kdeplot(df_details['v4'])
plt.xlabel('Feature v4')
# display the plot
plt.show()

# %% [markdown]
# <b>Inference</b> -
#
# 1) The data is a PCA data which means that it is already transformed and Scaled.
# 2) From the graph it can bbe observed that maximum datta points lies greater than +5 which indicates that the graph is positively or right skewed
# 3) It is also seen that the distribution graph have 2 peeks which means it is a bimodal graph.

# %%
#5) For v5
plt.subplots(2,0,figsize=(15,5))
plt.title("Distribution of v5 feature")
sns.boxplot(df_details['v5'])
plt.xlabel('Feature v5')

plt.subplots(1,0,figsize=(15,5))
plt.title("Distribution of v5 feature")
sns.kdeplot(df_details['v5'])
plt.xlabel('Feature v5')
# display the plot
plt.show()

# %% [markdown]
# <b>Inference</b> -
#
# 1) The data is a PCA data which means that it is already transformed and Scaled.
# 2) From the graph it can bbe observed that maximum datta points lies below 0 which indicates that the graph is left or negatively skewed.
# 3) It is also seen that the distribution graph have only 1 peek which means it is a unimodal graph.

# %%
#6) For v6
plt.subplots(2,0,figsize=(15,5))
plt.title("Distribution of v6 feature")
sns.boxplot(df_details['v6'])
plt.xlabel('Feature v6')

plt.subplots(1,0,figsize=(15,5))
plt.title("Distribution of v6 feature")
sns.kdeplot(df_details['v6'])
plt.xlabel('Feature v6')
# display the plot
plt.show()

# %% [markdown]
# <b>Inference</b> -
#
# 1) The data is a PCA data which means that it is already transformed and Scaled.
# 2) From the graph it can bbe observed that maximum data points lies greater than 0 which indicates that the graph is positively or right skewed
# 3) It is also seen that the distribution graph have only 1 peek which means it is a unimodal graph.

# %%
#For time column - Before Scaling
plt.subplots(2,0,figsize=(15,5))
plt.title("Distribution of Time feature")
sns.boxplot(df_details['time'])
plt.xlabel('Feature Time')

plt.subplots(1,0,figsize=(15,5))
plt.title("Distribution of Time feature")
sns.kdeplot(df_details['time'])
plt.xlabel('Feature Time')
# display the plot
plt.show()

# %% [markdown]
# <b>Inference</b> -
#
# 1) This time feature is not scaled or transformed due to which the range of values we are getting in the distribution graph is quite high. Hence, for this feature scaling needss to be performed.
# 2) It is also seen that the distribution graph have 2 peaks which makes it a bimodal graph
# 3) From the graph it can be observed that maximum data points lies greater than 0.

# %%
#7) Time column - For that Scaling is performed
from sklearn.preprocessing import StandardScaler
s=StandardScaler()

df_details['timeScaled']=s.fit_transform(df_details[['time']])
df_details.head()
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          v8        v9  ...       v22       v23       v24       v25       v26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
#7) For Time
plt.subplots(2,0,figsize=(15,5))
plt.title("Distribution of Time feature")
sns.boxplot(df_details['timeScaled'])
plt.xlabel('Feature Time')

plt.subplots(1,0,figsize=(15,5))
plt.title("Distribution of Time feature")
sns.kdeplot(df_details['timeScaled'])
plt.xlabel('Feature Time')
# display the plot
plt.show()

# %%
#From the above graph it can be inferred that time feature has no outliers and the distribution graph is also bimodal.

# %% [markdown]
# <b>Inference</b> -
#
# 1) The above analysis is done after scaling the time feature hence the range of values that has generated after scaling is in proper range.
# 2) We have used standard scalar scaling method because it is observed that before scaling no outlier is observed within the boxplot graph.
# 3) It is also seen that the distribution graph have 2 peaks which makes it a bimodal graph and the patttern of the graph is not changed after scaling.

# %%
#8) for v7

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v7 feature")
sns.boxplot(df_details['v7'])
plt.xlabel('Feature v7')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v7 feature")
sns.kdeplot(df_details['v7'])
plt.xlabel('Feature v7')
# display the plot
plt.show()

# %% [markdown]
# Inference of V7-
#
# 1)The obeserved data for V7 feature is a PCA data (already transformed data and scaled).
#
# 2)From the graph it can be observed that maximum data points lies on 0 which indicates that it is closed to normal distributed.
#
# 3)The graph contains only one peek hence it is a unimodal graph.

# %%
#9) for v8

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v8 feature")
sns.boxplot(df_details['v8'])
plt.xlabel('Feature v8')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v8 feature")
sns.kdeplot(df_details['v8'])
plt.xlabel('Feature v8')
# display the plot
plt.show()

# %% [markdown]
# Inference of V8-
#
# #1)The obeserved data for V8 feature is a PCA data (already transformed data and scaled)
#
# #2)From the graph it can be observed that maximum data points lies on 0 which indicates that it is closed to normal distributed.
#
# #3)The graph contains only one peek hence it is a unimodal graph.

# %%
#10) for v9

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v9 feature")
sns.boxplot(df_details['v9'])
plt.xlabel('Feature v9')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v9 feature")
sns.kdeplot(df_details['v9'])
plt.xlabel('Feature v9')
# display the plot
plt.show()

# %% [markdown]
# Inference of V9
#
# #1)The obeserved data for V9 feature is a PCA data (already transformed data and scaled).
#
# #2)From the graph it can be observed that maximum data points lies on 0 which indicates that it is closed to normal distributed.
#
# #3)The graph contains only one peek hence it is a unimodal graph.

# %%
#11) for v10

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v10 feature")
sns.boxplot(df_details['v10'])
plt.xlabel('Feature v10')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v10 feature")
sns.kdeplot(df_details['v10'])
plt.xlabel('Feature v10')
# display the plot
plt.show()

# %% [markdown]
# Inference of V10
#
# #1)The obeserved data for V10 feature is a PCA data (already transformed data and scaled)
#
# #2)From the graph it can be observed that maximum data points lies on 0 which indicates that it is closed to normal distributed.
#
# #3)The graph contains only one peek hence it is a unimodal graph.

# %%
#12) for v11

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v11 feature")
sns.boxplot(df_details['v11'])
plt.xlabel('Feature v11')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v11 feature")
sns.kdeplot(df_details['v11'])
plt.xlabel('Feature v11')
# display the plot
plt.show()

# %% [markdown]
# Inference of V11
#
# #1)The obeserved data for V11 feature is a PCA data (already transformed data and scaled)
#
# #2)From the graph it can be observed that maximum data points lies on 0 which indicates that it is closed to normal distributed.
#
# #3)The graph contains only one peek hence it is a unimodal graph.

# %%
#13) for v12

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v12 feature")
sns.boxplot(df_details['v12'])
plt.xlabel('Feature v12')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v12 feature")
sns.kdeplot(df_details['v12'])
plt.xlabel('Feature v12')
# display the plot
plt.show()

# %% [markdown]
# Inference of V12
#
# #1)The obeserved data for V12 feature is a PCA data (already transformed data and scaled)
#
# #2)From the graph it can be observed that maximum data points lies below -5 which indicates that it is nearly negatively skewed or left skewed .
#
# #3)The graph contains only one peek hence it is a unimodal graph.

# %%
#14) for v13

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v13 feature")
sns.boxplot(df_details['v13'])
plt.xlabel('Feature v13')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v13 feature")
sns.kdeplot(df_details['v13'])
plt.xlabel('Feature v13')
# display the plot
plt.show()

# %% [markdown]
# Inference of V13
#
# #1)The obeserved data for V13 feature is a PCA data (already transformed data and scaled)
#
# #2)From the graph it can be observed that maximum data points lies on 0 which indicates that it is closed to normal distributed.
#
# #3)The graph contains only one peek hence it is a unimodal graph.

# %%
#15) for v14

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v14 feature")
sns.boxplot(df_details['v14'])
plt.xlabel('Feature v14')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v14 feature")
sns.kdeplot(df_details['v14'])
plt.xlabel('Feature v14')
# display the plot
plt.show()

# %%
#16) for v15
plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v15 feature")
sns.boxplot(df_details['v15'])
plt.xlabel('Feature v15')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v15 feature")
sns.kdeplot(df_details['v15'])
plt.xlabel('Feature v15')
# display the plot
plt.show()

# %%
#17) for v16
plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v16 feature")
sns.boxplot(df_details['v16'])
plt.xlabel('Feature v16')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v16 feature")
sns.kdeplot(df_details['v16'])
plt.xlabel('Feature v16')
# display the plot
plt.show()

# %%
#18) for v17
plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v17 feature")
sns.boxplot(df_details['v17'])
plt.xlabel('Feature v17')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v17 feature")
sns.kdeplot(df_details['v17'])
plt.xlabel('Feature v17')
# display the plot
plt.show()

# %% [markdown]
# As we can see from the above figures, Features V14 and V17 has most of the values in the left whisker. The Inter Quartile Range is almost equal in V14 and V17 features. In feature V15,values are almost distributed in both right and left whiskers and Inter Quartile Range is quite large when compared to other features. In feature V16, The values are more in left whisker and The IQR is similar to V14 and V17.

# %%
#19) for v18
plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v18 feature")
sns.boxplot(df_details['v18'])
plt.xlabel('Feature v18')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v18 feature")
sns.kdeplot(df_details['v18'])
plt.xlabel('Feature v18')
# display the plot
plt.show()

# %%
#20) for v19
plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v19 feature")
sns.boxplot(df_details['v19'])
plt.xlabel('Feature v19')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v19 feature")
sns.kdeplot(df_details['v19'])
plt.xlabel('Feature v19')
# display the plot
plt.show()

# %%
#21) for v20
plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v20 feature")
sns.boxplot(df_details['v20'])
plt.xlabel('Feature v20')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v20 feature")
sns.kdeplot(df_details['v20'])
plt.xlabel('Feature v20')
# display the plot
plt.show()

# %% [markdown]
# We can infer from the above figures that the IQR in V18 and V19 features are equal. Whereas the values are distributed more the in left whisker in V18 and values are distributed more in the right whisker in V19. IQR in V20 is very low comparing the other two features. The values in V20 are distributed almost equally in both sides.

# %%
#22) for v21
plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v21 feature")
sns.boxplot(df_details['v21'])
plt.xlabel('Feature v21')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v21 feature")
sns.kdeplot(df_details['v21'])
plt.xlabel('Feature v21')
# display the plot
plt.show()

# %% [markdown]
# Inference -
#
# 1) The data is a PCA data which means that it is already transformed and Scaled. 2) From the graph it can bbe observed that maximum datta points lies below 0 which indicates that the graph is left or negatively skewed. 3) It is also seen that the distribution graph have only 1 peek which means it is a unimodal graph

# %%
#23) for v22

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v22 feature")
sns.boxplot(df_details['v22'])
plt.xlabel('Feature v22')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v22 feature")
sns.kdeplot(df_details['v22'])
plt.xlabel('Feature v22')
# display the plot
plt.show()

# %% [markdown]
# Inference -
#
# 1) The data is a PCA data which means that it is already transformed and Scaled. 2) From the graph it can bbe observed that maximum datta points lies below -10 which indicates that the graph is left or negatively skewed. 3) It is also seen that the distribution graph have only 2 peek which means it is a bimodal graph

# %%
#24) for v23

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v23 feature")
sns.boxplot(df_details['v23'])
plt.xlabel('Feature v23')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v23 feature")
sns.kdeplot(df_details['v23'])
plt.xlabel('Feature v23')
# display the plot
plt.show()

# %% [markdown]
# Inference -
#
# 1) The data is a PCA data which means that it is already transformed and Scaled. 2) From the graph it can be observed that maximum data points lies below -10 which indicates that it is negatively skewed or left skewed 3) The graph contains only one peek hence it is a unimodal graph

# %%
#25) for v24

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v24 feature")
sns.boxplot(df_details['v24'])
plt.xlabel('Feature v24')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v24 feature")
sns.kdeplot(df_details['v24'])
plt.xlabel('Feature v24')
# display the plot
plt.show()

# %% [markdown]
# inference
#
# 1) The data is a PCA data which means that it is already transformed and Scaled.2) From the graph it can be observed that maximum data points lies below -2 which indicates that it is negatively skewed or left skewed 3) The graph contains only  one peek hence it is a unimodal graph

# %%
#26) for v25

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v25 feature")
sns.boxplot(df_details['v25'])
plt.xlabel('Feature v25')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v25 feature")
sns.kdeplot(df_details['v25'])
plt.xlabel('Feature v25')
# display the plot
plt.show()

# %% [markdown]
# inference
#
# 1) The data is a PCA data which means that it is already transformed and Scaled.2) From the graph it can be observed that maximum data points lies below -2.5 which indicates that it is negatively skewed or left skewed 3) The graph contains  two peek hence it is a bimodal graph

# %%
#27) for v26

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v26 feature")
sns.boxplot(df_details['v26'])
plt.xlabel('Feature v26')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v26 feature")
sns.kdeplot(df_details['v26'])
plt.xlabel('Feature v26')
# display the plot
plt.show()

# %% [markdown]
# inference
#
# 1) The data is a PCA data which means that it is already transformed and Scaled.2) From the graph it can be observed that maximum data points lies below 3 which indicates that it is positively skewed or right skewed 3) The graph contains only two peek hence it is a bimodal graph

# %%
#28) for v27

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v27 feature")
sns.boxplot(df_details['v27'])
plt.xlabel('Feature v27')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v27 feature")
sns.kdeplot(df_details['v27'])
plt.xlabel('Feature v27')
# display the plot
plt.show()

# %% [markdown]
# inference
#
# 1) The data is a PCA data which means that it is already transformed and Scaled.2) From the graph it can be observed that maximum data points lies below 10 which indicates that it is positively skewed or right skewed 3) The graph contains only one peek hence it is a unimodal graph

# %%
#29) for v28

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v28 feature")
sns.boxplot(df_details['v28'])
plt.xlabel('Feature v28')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of v28 feature")
sns.kdeplot(df_details['v28'])
plt.xlabel('Feature v28')
# display the plot
plt.show()

# %% [markdown]
# inference
#
# 1) The data is a PCA data which means that it is already transformed and Scaled.2) From the graph it can be observed that maximum data points lies above 20 which indicates that it is positively skewed or rightt skewed 3) The graph contains only one peek hence it is a unimodal graph

# %%
# amount column - For that Scaling is performed
from sklearn.preprocessing import StandardScaler
s=StandardScaler()

df_details['amountScaled']=s.fit_transform(df_details[['amount']])
df_details.head()
# Out:
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          v8        v9  ...       v22       v23       v24       v25       v26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
#30) for amount

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of amountScaled feature")
sns.boxplot(df_details['amountScaled'])
plt.xlabel('Feature amountScaled')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of amountScaled feature")
sns.kdeplot(df_details['amountScaled'])
plt.xlabel('Feature amountScaled')
# display the plot
plt.show()

# %% [markdown]
# inference
#
# 1) The data is a PCA data which means that it is already transformed and Scaled.2) From the graph it can be observed that maximum data points lies on the positive side  which indicates that it is negatively skewed or left skewed 3) The graph contains only one peek hence it is a unimodal graph

# %%
#31) for class

plt.figure(figsize = (15,8))
plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of class feature")
sns.boxplot(df_details['class'])
plt.xlabel('Feature class')

plt.subplots(1,1,figsize=(15,5))
plt.title("Distribution of class feature")
sns.kdeplot(df_details['class'])
plt.xlabel('Feature class')
# display the plot
plt.show()

# %% [markdown]
# Inference -
#
# 1) From the distribution plot it is observed that the graph is right skewed or positively skewed.
# 2) It is also observed that it not normally distributed from the visualization

# %% [markdown]
# # Bivariate Analysis for each feature with the Target variable

# %%
df_target=df_details['class']

# %%
#1) For v1
plt.figure(figsize = (15,8))
plt.title("class v/s v1 feature")
sns.stripplot(df_target,df_details['v1'],jitter=0.05,linewidth=1)
#sns.boxplot(df_target,df_details['v1'])

# %% [markdown]
# <b>Inference</b> -
#
# 1) From the above visualization it is observed that the Class having False value that is non-Fraudulent is more dense as compared to that of True value which is Fraudulent which indicates that the more number of transaction that has happened under v1 feature in the past is the non-Fraudulent one as compared to the fraudulent one.
#
# 2) The non-fraudulent one lies under the scale of -25 to 0 and that of fraudulent one lies on the scale of -9 to 0.
#
# 3) So, it can be inferred that the transaction that will occur for v1 feature has the possibility to be a non-Fraudulent one if the transaction happens between -25 to 0 scale.

# %%
#2) For v2
plt.figure(figsize = (15,8))
plt.title("class v/s v2 feature")
sns.stripplot(df_details['class'],df_details['v2'],jitter=0.05,linewidth=1)

# %% [markdown]
# <b>Inference</b> -
#
# 1) From the above visualization it is observed that the Class having False value that is non-Fraudulent is more dense as compared to that of True value which is Fraudulent which indicates that maximum transaction that has happened under v2 feature in the past is the non-Fraudulent one.
#
# 2) So, it can be inferred that the transaction that will occur for v2 feature has the possibility to be a non-Fraudulent one if the scale is in between 0 to -30.

# %%
#3) For v3
plt.figure(figsize = (15,8))
plt.title("class v/s v3 feature")
sns.stripplot(df_details['class'],df_details['v3'],jitter=0.05,linewidth=1)

# %% [markdown]
# <b>Inference</b> -
#
# 1) From the above visualization it is observed that the Class having False value that is non-Fraudulent is more dense as compared to that of True value which is Fraudulent as it is a bit scattered which indicates that maximum transaction that has happened under v3 feature for the scale of -15 to 0 in the past is the non-Fraudulent one and for the scale of -15 to -30 the transaction could be a fraudulent one.

# %%
#4) For v4
plt.figure(figsize = (15,8))
plt.title("class v/s v4 feature")
sns.stripplot(df_details['class'],df_details['v4'],jitter=0.05,linewidth=1)

# %% [markdown]
# <b>Inference</b> -
#
# 1) From the above visualization it is observed that the Class having False value that is non-Fraudulent is more dense as compared to that of True value which is Fraudulent which indicates that the transaction that has happened under v4 feature for the scale of 8 to -5 is a non-fraudulent one and for the scale of 0 to 7 the transaction happened is a fraudulent one.
#
# 2) So, it can be inferred that the transaction that will occur for v4 feature has the possibility to be a non-Fraudulent one if the transaction is happening under the scale of 8 to -5.

# %%
#5) For v5
plt.figure(figsize = (15,8))
plt.title("class v/s v5 feature")
sns.stripplot(df_details['class'],df_details['v5'],jitter=0.05,linewidth=1)

# %% [markdown]
# <b>Inference</b> -
#
# From the above visualization it is observed that the Class having False value that is non-Fraudulent is more dense as compared to that of True value which is Fraudulent which indicates that the transaction that has happened under v5 feature in the past is the non-Fraudulent one and the number of non-fraudulent transaction happened is more than that of fraudulent transaction.

# %%
#6) For v6
plt.figure(figsize = (15,8))
plt.title("class v/s v6 feature")
sns.stripplot(df_details['class'],df_details['v6'],jitter=0.05,linewidth=1)

# %% [markdown]
# <b>Inference</b> -
#
# 1) From the above visualization it is observed that the Class having False value that is non-Fraudulent one is more dense as compared to that of True value which is the Fraudulent one which indicates that there is more number of transaction that has happened under v6 feature is a non-fraudulent one as compared to the fraudulent transactions that has happened.
#
# 2) The maximum non-fraudulent transaction has happened for the scale of -19 to +19.
#
# 3) So, it can be inferred that the transaction that will occur for v6 feature has the possibility to be a non-Fraudulent one if the scale lies for -19 to +19 and can be a fraudulent one if the scale lies between +5 to -5.

# %%
#7) For timeScaled
plt.figure(figsize = (15,8))
plt.title("class v/s Time feature")
sns.stripplot(df_details['class'],df_details['timeScaled'],jitter=0.05,linewidth=1)

# %% [markdown]
# <b>Inference</b> -
#
# 1) From the above visualization it is observed that the Class having False value that is non-Fraudulent is more dense as compared to that of True value which is Fraudulent which indicates that more number of transactions that has happened under time feature in the past is the non-Fraudulent one.

# %%
#8) For v7
plt.figure(figsize = (15,8))
plt.title("class v/s v7 feature")
sns.stripplot(df_target,df_details['v7'],jitter=0.05,linewidth=1)

# %% [markdown]
# #1)From the above visualization it is observed that the class having false value that is non-fradulent is more dense as compared to that of the true value which is Fraudulent which indicates that the more number of transaction that has happened under V7 feature in the past is the non-Fraudulent one as compared to the fraudulent one.
#
# #2)The non-fraudulent one lies under the scale of -25 to 100 and that of fraudulent one lies on the scale of -25 to 0.
#
# #3)So, it can be inferred that the transaction that will occur for v7 feature has the possibility to be a non-fraudulent one. if the transaction happens between -25 to 100 scale.

# %%
#9) For v8
plt.figure(figsize = (15,8))
plt.title("class v/s v8 feature")
sns.stripplot(df_target,df_details['v8'],jitter=0.05,linewidth=1)

# %% [markdown]
# Inference of V8-
#
# #1)From the above visualization it is observed that the class having false value that is non-fradulent is more dense as compared to that of the true value which is Fraudulent which indicates that the more number of transaction that has happened under V8 feature in the past is the non-Fraudulent one as compared to the fraudulent one.
#
# #2)The non-fraudulent one lies under the scale of -60 to 0 and that of fraudulent one lies on the scale of -40 to 0.
#
# #3)So, it can be inferred that the transaction that will occur for V8 feature has the possibility to be a non-fraudulent one. if the transaction happens between -60 to 0 scale.

# %%
#10) For v9
plt.figure(figsize = (15,8))
plt.title("class v/s v9 feature")
sns.stripplot(df_target,df_details['v9'],jitter=0.05,linewidth=1)

# %% [markdown]
# Inference of V9-
#
# #1)From the above visualization it is observed that the class having false value that is non-fradulent is more dense as compared to that of the true value which is Fraudulent which indicates that the more number of transaction that has happened under V9 feature in the past is the non-Fraudulent one as compared to the fraudulent one.
#
# #2)The non-fraudulent one lies under the scale of -5 to 15 and that of fraudulent one lies on the scale of -10 to 0.
#
# #3)So, it can be inferred that the transaction that will occur for V9 feature has the possibility to be a non-fraudulent one. if the transaction happens between -5 to 15 scale.

# %%
#11) For v10
plt.figure(figsize = (15,8))
plt.title("class v/s v10 feature")
sns.stripplot(df_target,df_details['v10'],jitter=0.05,linewidth=1)

# %% [markdown]
# Inference of V10-
#
# #1)From the above visualization it is observed that the class having false value that is non-fradulent is more dense as compared to that of the true value which is Fraudulent which indicates that the more number of transaction that has happened under V10 feature in the past is the non-Fraudulent one as compared to the fraudulent one.
#
# #2)The non-fraudulent one lies under the scale of -10 to 200 and that of fraudulent one lies on the scale of -20 to 0.
#
# #3)So, it can be inferred that the transaction that will occur for V10 feature has the possibility to be a non-fraudulent one. if the transaction happens between -10 to 20 scale.

# %%
#12) For v11
plt.figure(figsize = (15,8))
plt.title("class v/s v11 feature")
sns.stripplot(df_target,df_details['v11'],jitter=0.05,linewidth=1)

# %% [markdown]
# Inference of V11-
#
# #1)From the above visualization it is observed that the class having false value that is non-fradulent is more dense as compared to that of the true value which is Fraudulent which indicates that the more number of transaction that has happened under V11 feature in the past is the non-Fraudulent one as compared to the fraudulent one.
#
# #2)The non-fraudulent one lies under the scale of -2.5 to 10.0 and that of fraudulent one lies on the scale of -0.0 to 10.0.
#
# #3)So, it can be inferred that the transaction that will occur for V11 feature has the possibility to be a non-fraudulent one. if the transaction happens between -2.5 to 10.0 scale.

# %%
#13) For v12
plt.figure(figsize = (15,8))
plt.title("class v/s v12 feature")
sns.stripplot(df_target,df_details['v12'],jitter=0.05,linewidth=1)

# %% [markdown]
# Inference of V12-
#
# #1)From the above visualization it is observed that the class having false value that is non-fradulent is more dense as compared to that of the true value which is Fraudulent which indicates that the more number of transaction that has happened under V12 feature in the past is the non-Fraudulent one as compared to the fraudulent one.
#
# #2)The non-fraudulent one lies under the scale of -15 to 5 and that of fraudulent one lies on the scale of -15 to 0.
#
# #3)So, it can be inferred that the transaction that will occur for V12 feature has the possibility to be a non-fraudulent one. if the transaction happens between -15 to 50 scale.

# %%
#14) For v13
plt.figure(figsize = (15,8))
plt.title("class v/s v13 feature")
sns.stripplot(df_target,df_details['v13'],jitter=0.05,linewidth=1)

# %% [markdown]
# Inference of V13-
#
# #1)From the above visualization it is observed that the class having false value that is non-fradulent is more dense as compared to that of the true value which is Fraudulent which indicates that the more number of transaction that has happened under V13 feature in the past is the non-Fraudulent one as compared to the fraudulent one.
#
# #2)The non-fraudulent one lies under the scale of -4 to 6 and that of fraudulent one lies on the scale of -2 to 2.
#
# #3)So, it can be inferred that the transaction that will occur for V13 feature has the possibility to be a non-fraudulent one. if the transaction happens between -4 to 6 scale.

# %%
df_target=df_details['class']
#15) For v14
plt.figure(figsize = (15,8))
plt.title("class v/s v14 feature")
sns.stripplot(df_target,df_details['v14'],jitter=0.05,linewidth=1)

# %% [markdown]
# As we can see from the above strip plot, the Class having False value is non-fraudulent which is more dense and True value which is less dense is Fraudulent. It indicates that more number of transaction that has happened under V14 feature in the past is the non-Fraudulent one as compared to the fraudulent one. The non-Fraudulent one lies under the scale of -16 to 7. The Fraudulent one lies between -20 to 2. It can be inferred that the transaction that will occur for V14 feature could be Fraudulent and non-Fraudulent ones. If the transaction is Fraudulent one then the values should be present between -16 to 7.

# %%
#16) For v15
plt.figure(figsize = (15,8))
plt.title("class v/s v15 feature")
sns.stripplot(df_target,df_details['v15'],jitter=0.05,linewidth=1)

# %% [markdown]
# As we can see from the above strip plots of V15 and V19 features, the Class having False value is non-fraudulent which is more dense and True value which is less dense is Fraudulent. It indicates that more number of transaction that has happened under V15 and V19 features in the past is the non-Fraudulent one as compared to the fraudulent one. The non-Fraudulent one lies under the scale of -4 to 6 in V15 and -3 to 4 in V19. The Fraudulent one lies between -4 to 1 in V15 and -3 to 5 in V19. It can be inferred that the transaction that will occur for V15 feature could be Fraudulent and non-Fraudulent ones. If the transaction is Fraudulent one then the values should be present between -4 to 6 in V15 and -3 to 4 in V19.

# %%
#17) For v16
plt.figure(figsize = (15,8))
plt.title("class v/s v16 feature")
sns.stripplot(df_target,df_details['v16'],jitter=0.05,linewidth=1)

# %%
#18) For v17
plt.figure(figsize = (15,8))
plt.title("class v/s v17 feature")
sns.stripplot(df_target,df_details['v17'],jitter=0.05,linewidth=1)

# %% [markdown]
# As we can see from the above strip plots of V16 and V17 features, the Class having False value is non-fraudulent which is more dense and True value which is less dense is Fraudulent. It indicates that more number of transaction that has happened under V16 and V17 features in the past is the non-Fraudulent one as compared to the fraudulent one. The non-Fraudulent one lies under the scale of -10 to 8 in V16 and -16 to 9 in V17. The Fraudulent one lies between -15 to 2 in V16 and -25 to 5 in V17. It can be inferred that the transaction that will occur for V15 feature could be Fraudulent and non-Fraudulent ones. If the transaction is Fraudulent one then the values should be present between -10 to 8 in V16 and -16 to 9 in V17.

# %%
#19) For v18
plt.figure(figsize = (15,8))
plt.title("class v/s v18 feature")
sns.stripplot(df_target,df_details['v18'],jitter=0.05,linewidth=1)

# %% [markdown]
# As we can see from the above strip plot, the Class having False value is non-fraudulent which is more dense and True value which is less dense is Fraudulent. It indicates that more number of transaction that has happened under V18 feature in the past is the non-Fraudulent one as compared to the fraudulent one. The non-Fraudulent one lies under the scale of -5 to 5. The Fraudulent one lies between -9 to 3. It can be inferred that the transaction that will occur for V18 feature could be Fraudulent and non-Fraudulent ones. If the transaction is Fraudulent one then the values should be present between -10 to 4.

# %%
#20) For v19
plt.figure(figsize = (15,8))
plt.title("class v/s v19 feature")
sns.stripplot(df_target,df_details['v19'],jitter=0.05,linewidth=1)

# %%
#21) For v20
plt.figure(figsize = (15,8))
plt.title("class v/s v20 feature")
sns.stripplot(df_target,df_details['v20'],jitter=0.05,linewidth=1)

# %% [markdown]
# As we can see from the above strip plot, the Class having False value is non-fraudulent which is more dense and True value which is less dense is Fraudulent. It indicates that more number of transaction that has happened under V20 feature in the past is the non-Fraudulent one as compared to the fraudulent one. The non-Fraudulent one lies under the scale of -25 to 40. The Fraudulent one lies between 0 to 10. It can be inferred that the transaction that will occur for V18 feature could be Fraudulent and non-Fraudulent ones. If the transaction is Fraudulent one then the values should be present between -25 to 40.

# %%
df_target=df_details['class']
#22) For v21
plt.figure(figsize = (15,8))
plt.title("class v/s v21 feature")
sns.stripplot(df_target,df_details['v21'],jitter=0.05,linewidth=1)

# %%
#23) For v22
plt.figure(figsize = (15,8))
plt.title("class v/s v22 feature")
sns.stripplot(df_target,df_details['v22'],jitter=0.05,linewidth=1)

# %%
#24) For v23
plt.figure(figsize = (15,8))
plt.title("class v/s v23 feature")
sns.stripplot(df_target,df_details['v23'],jitter=0.05,linewidth=1)

# %%
#25)  For v24
plt.figure(figsize = (15,8))
plt.title("class v/s v24 feature")
sns.stripplot(df_target,df_details['v24'],jitter=0.05,linewidth=1)

# %%
#26)  For v25
plt.figure(figsize = (15,8))
plt.title("class v/s v25 feature")
sns.stripplot(df_target,df_details['v25'],jitter=0.05,linewidth=1)

# %%
#27) For v26
plt.figure(figsize = (15,8))
plt.title("class v/s v26 feature")
sns.stripplot(df_target,df_details['v26'],jitter=0.05,linewidth=1)

# %%
#28) For v27
plt.figure(figsize = (15,8))
plt.title("class v/s v27 feature")
sns.stripplot(df_target,df_details['v27'],jitter=0.05,linewidth=1)

# %%
#29) For v28
plt.figure(figsize = (15,8))
plt.title("class v/s v28 feature")
sns.stripplot(df_target,df_details['v28'],jitter=0.05,linewidth=1)

# %%
#30)  For amountscaled
plt.figure(figsize = (15,8))
plt.title("class v/s amountScaled feature")
sns.stripplot(df_target,df_details['amountScaled'],jitter=0.05,linewidth=1)

# %% [markdown]
# # Model Building

# %% [markdown]
# <b>1) Decision Tree Model</b>

# %%
import os 
import warnings
warnings.filterwarnings('ignore')
#Packages related to data importing, manipulation, exploratory data #analysis, data understanding

#Setting plot sizes and type of plot

from matplotlib.backends.backend_pdf import PdfPages
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics
from sklearn.impute import MissingIndicator, SimpleImputer
from sklearn.preprocessing import  PolynomialFeatures, KBinsDiscretizer, FunctionTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, LabelBinarizer, OrdinalEncoder
import statsmodels.formula.api as smf
import statsmodels.tsa as tsa
from sklearn.linear_model import LogisticRegression, LinearRegression, ElasticNet, Lasso, Ridge
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, export_graphviz
from sklearn.svm import LinearSVC, LinearSVR, SVC, SVR
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score,balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
from sklearn.utils import shuffle
from imblearn.under_sampling import RandomUnderSampler
from sklearn.ensemble import RandomForestClassifier

# %%
X = df_details.drop('class', axis = 1).values
y = df_details['class'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1)

# %%
X_train.size
# Out:
# 6408150

# %%
unique,counts=np.unique(y_train,return_counts=True)
result=np.vstack([unique,counts]).T
result
# Out:
# array([[     0, 213224],
#        [     1,    381]], dtype=int64)

# %% [markdown]
# <b>From the above array this can be inferred that the biasness is there in the dataset as the number of non-Fraudulent transactions are much more higher than the Fraudulent transactions. Hence, in order to overcome this biasness we are performing oversampling and undersampling methods.</b>

# %%
over_X , over_y = SMOTE().fit_resample(X_train, y_train)
over_X , over_y = shuffle(over_X,over_y,random_state = 0)

# %%
unique,counts=np.unique(over_y,return_counts=True)
result=np.vstack([unique,counts]).T
result
# Out:
# array([[     0, 213224],
#        [     1, 213224]], dtype=int64)

# %%
len(over_X)
# Out:
# 426448

# %%
len(X_train)
# Out:
# 213605

# %%
under_X , under_y = RandomUnderSampler(random_state=0).fit_resample(X_train,y_train)
under_X , under_y = shuffle(under_X,under_y,random_state = 0)

# %%
unique,counts=np.unique(under_y,return_counts=True)
result=np.vstack([unique,counts]).T
result
# Out:
# array([[  0, 381],
#        [  1, 381]], dtype=int64)

# %% [markdown]
# <b>Decision Tree without sampling</b>

# %%
DT = DecisionTreeClassifier(max_depth = 4, criterion = 'entropy')
tree_yhat = DT.fit(X_train, y_train)
tree_yhat
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
dt_yhat = DT.predict(X_test)
dt_yhat
# Out:
# array([False, False, False, ..., False, False, False])

# %%
#Checking the accuracy of the model
print('Accuracy score of the Decision Tree model is',accuracy_score(y_test,dt_yhat))
# Out:
# Accuracy score of the Decision Tree model is 0.9993539507317211

# %%
#Checking the F1-Score for the decision tree model

# %%
print('F1 score of the Decision Tree model is',f1_score(y_test,dt_yhat))
# Out:
# F1 score of the Decision Tree model is 0.7745098039215685

# %%
#Checking the confusion matrix

# %%
confusion_matrix(y_test,dt_yhat, labels = [0, 1])
# Out:
# array([[71077,    14],
#        [   32,    79]], dtype=int64)

# %%
#Classification Report of Decision Tree
print(classification_report(y_test,dt_yhat))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     71091
#         True       0.85      0.71      0.77       111
#
#     accuracy                           1.00     71202
#    macro avg       0.92      0.86      0.89     71202
# weighted avg       1.00      1.00      1.00     71202

# %% [markdown]
# <b>Here, the first row represents positive and the second row represents negative. So, we have 71077 as true positive and 14 are false positive. That says, out of 71077+14=71091, we have 71077 that are successfully classified as a normal transaction and 14 were falsely classified as normal — but they were fraudulent.
#
# So as the values present in the dataset are imbalanced in number for fraudulent and non-fraudulent one we have yet not achieved the accuracy.
#
# Hence, in order to overcome this scenario oversampling and undersampling of data is done.</b>

# %% [markdown]
# <b>2. Logistic Regression</b>

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr_yhat = lr.predict(X_test)
lr_yhat
# Out:
# array([False, False, False, ..., False, False, False])

# %%
#Checking the accuracy of the model

# %%
print('Accuracy score of the Logistic Regression model is',accuracy_score(y_test,lr_yhat))
# Out:
# Accuracy score of the Logistic Regression model is 0.9987500351113733

# %%
#Checking the F1-Score for the Logistic Regression model

# %%
print('F1 score of the Logistic Regression model is',f1_score(y_test, lr_yhat))
# Out:
# F1 score of the Logistic Regression model is 0.611353711790393

# %%
confusion_matrix(y_test,lr_yhat)
# Out:
# array([[71043,    48],
#        [   41,    70]], dtype=int64)

# %%
print(classification_report(y_test,lr_yhat))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     71091
#         True       0.59      0.63      0.61       111
#
#     accuracy                           1.00     71202
#    macro avg       0.80      0.81      0.81     71202
# weighted avg       1.00      1.00      1.00     71202

# %% [markdown]
# <b>3.Random Forest Model</b>

# %% [markdown]
# <b>Random Forest Model without sampling</b>

# %%
rf = RandomForestClassifier(max_depth = 4)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=4)

# %%
rf_yhat = rf.predict(X_test)
rf_yhat
#Checking the accuracy of our Random Forest Model
print('Accuracy score of the Random Forest model is',accuracy_score(y_test, rf_yhat))
#Checking the F1-Score of the Random Forest Model
print('F1 score of the Random Forest model is',f1_score(y_test, rf_yhat))
# Out:
# Accuracy score of the Random Forest model is 0.9993399061824106
# F1 score of the Random Forest model is 0.7564766839378239

# %%
print(confusion_matrix(y_test,rf_yhat))
# Out:
# [[71082     9]
#  [   38    73]]

# %%
print(classification_report(y_test,rf_yhat))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     71091
#         True       0.89      0.66      0.76       111
#
#     accuracy                           1.00     71202
#    macro avg       0.94      0.83      0.88     71202
# weighted avg       1.00      1.00      1.00     71202

# %% [markdown]
# As we can see from classification report, support for 2 classes are highly imbalanced. This is due to the fact that fraudulent transactions are rare events as compared to normal transactions.
#
# From confusion matrix and classification report we can see that precision and recall for True (Fraudulent Transactions) class are not much satisfactory.
#
# Overall out of 111 Fraudulent transactions, our Random Forest Model could classify only 73 as True. 38 were misclassified as normal transactions.
#
# So, we can try sampling techniques like oversampling (SMOTE) and undersampling to see if model performances improve.
# We will try both techniques for the models used above.

# %% [markdown]
# <b>Decision Tree using oversampling</b>

# %%
DT_over = DecisionTreeClassifier(max_depth = 4, criterion = 'entropy')
tree_yhat = DT_over.fit(over_X, over_y)
tree_yhat
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
dt_yhat = DT_over.predict(X_test)
dt_yhat
# Out:
# array([False, False, False, ..., False, False, False])

# %%
confusion_matrix(y_test,dt_yhat, labels = [0, 1])
# Out:
# array([[69562,  1529],
#        [   15,    96]], dtype=int64)

# %%
print(classification_report(y_test,dt_yhat))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99     71091
#         True       0.06      0.86      0.11       111
#
#     accuracy                           0.98     71202
#    macro avg       0.53      0.92      0.55     71202
# weighted avg       1.00      0.98      0.99     71202

# %% [markdown]
# From the above classification report it can be observed that the precision and recall for this model is very less due to which we need to reject this model.

# %% [markdown]
# <b>Decision Tree using undersampling</b>

# %%
DT_under = DecisionTreeClassifier(max_depth = 4, criterion = 'entropy')
tree_yhat = DT_under.fit(under_X, under_y)
tree_yhat
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
dt_yhat = DT_under.predict(X_test)
dt_yhat
# Out:
# array([False, False, False, ...,  True, False, False])

# %%
confusion_matrix(y_test,dt_yhat, labels = [0, 1])
# Out:
# array([[68091,  3000],
#        [   14,    97]], dtype=int64)

# %%
print(classification_report(y_test,dt_yhat))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98     71091
#         True       0.03      0.87      0.06       111
#
#     accuracy                           0.96     71202
#    macro avg       0.52      0.92      0.52     71202
# weighted avg       1.00      0.96      0.98     71202

# %% [markdown]
# <b>Logistic Regression using Oversampling</b>

# %%
lr = LogisticRegression()
lr.fit(over_X, over_y)
# Out:
# LogisticRegression()

# %%
lr_yhat = lr.predict(X_test)
lr_yhat
# Out:
# array([False, False, False, ..., False, False, False])

# %%
confusion_matrix(y_test,lr_yhat)
# Out:
# array([[69944,  1147],
#        [   18,    93]], dtype=int64)

# %%
print(classification_report(y_test,lr_yhat))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99     71091
#         True       0.07      0.84      0.14       111
#
#     accuracy                           0.98     71202
#    macro avg       0.54      0.91      0.56     71202
# weighted avg       1.00      0.98      0.99     71202

# %% [markdown]
# <b>Logistic Regression using undersampling</b>

# %%
lr = LogisticRegression()
lr.fit(under_X, under_y)
# Out:
# LogisticRegression()

# %%
lr_yhat = lr.predict(X_test)
lr_yhat
# Out:
# array([False, False, False, ..., False, False, False])

# %%
confusion_matrix(y_test,lr_yhat)
# Out:
# array([[68339,  2752],
#        [   14,    97]], dtype=int64)

# %%
print(classification_report(y_test,lr_yhat))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.96      0.98     71091
#         True       0.03      0.87      0.07       111
#
#     accuracy                           0.96     71202
#    macro avg       0.52      0.92      0.52     71202
# weighted avg       1.00      0.96      0.98     71202

# %% [markdown]
# From the results above, it can be inferred that the precision and recall of all the models using sampling techniques did not perform well as compared to baseline models.
#
# Now, to improve performance we can try Grid Search on Hyper-parameters of best baseline model (Random Forest Model).

# %% [markdown]
# <b>Grid-Search on Random Forest</b>

# %% [markdown]
# Using cross-validation

# %%
#importing libraries
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import make_scorer
VERBOSE_OUTPUT_LEVEL = 3  #To visualize Grid search results
refit = True   #To fit the best model of grid search to training data
cv = 5   #cv - 5 fold cross validation during training

# %%
criterion = ['gini','entropy']
max_depth = [2,5]
min_samples_split = [2, 5]
param_grid = {'criterion': criterion, 'max_depth': max_depth, 'min_samples_split': min_samples_split}

# %%
clf = RandomForestClassifier(random_state=13, max_features='auto')
gs_cv = GridSearchCV(clf, param_grid, cv=cv, scoring='f1_micro', refit=refit, verbose=VERBOSE_OUTPUT_LEVEL)

# %%
gs_clf = gs_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_split=2;, score=0.999 total time=  45.8s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_split=2;, score=0.999 total time=  31.2s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_split=2;, score=0.999 total time=  34.2s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_split=2;, score=0.999 total time=  35.8s
# [CV 5/5] END criterion=gini, max_depth=2, min_samples_split=2;, score=0.999 total time=  37.7s
# [CV 1/5] END criterion=gini, max_depth=2, min_samples_split=5;, score=0.999 total time=  34.7s
# [CV 2/5] END criterion=gini, max_depth=2, min_samples_split=5;, score=0.999 total time=  34.4s
# [CV 3/5] END criterion=gini, max_depth=2, min_samples_split=5;, score=0.999 total time=  32.7s
# [CV 4/5] END criterion=gini, max_depth=2, min_samples_split=5;, score=0.999 total time=  33.9s
# ...

# %%
best_clf = gs_clf.best_estimator_
clf_params = gs_clf.best_params_
clf_score = gs_clf.best_score_
print(best_clf)
print(f"best score {clf_score}, best parameters {clf_params}")
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, random_state=13)
# best score 0.9994663046277006, best parameters {'criterion': 'entropy', 'max_depth': 5, 'min_samples_split': 2}

# %%
# score
accuracy = round(cross_val_score(best_clf, X, y, scoring=make_scorer(accuracy_score), cv = cv).mean(),4)
balanced_accuracy = round(cross_val_score(best_clf, X, y, scoring=make_scorer(balanced_accuracy_score), cv = cv).mean(),4)
f1_score = round(cross_val_score(best_clf, X, y, scoring=make_scorer(f1_score), cv = cv).mean(),4)
print(f"Accuracy on Training Set : {accuracy}")
print(f"Balanced Accuracy on Training Set : {balanced_accuracy}")
print(f"F1 Score on Training Set : {f1_score}")
# Out:
# Accuracy on Training Set : 0.9994
# Balanced Accuracy on Training Set : 0.8809
# F1 Score on Training Set : 0.8128

# %%
dt_yhat = best_clf.predict(X_test)
dt_yhat
# Out:
# array([False, False, False, ..., False, False, False])

# %%
confusion_matrix(y_test,dt_yhat)
# Out:
# array([[71082,     9],
#        [   32,    79]], dtype=int64)

# %%
print(classification_report(y_test,dt_yhat))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     71091
#         True       0.90      0.71      0.79       111
#
#     accuracy                           1.00     71202
#    macro avg       0.95      0.86      0.90     71202
# weighted avg       1.00      1.00      1.00     71202

# %% [markdown]
# From the results of Grid-Search the precision and recall of the random forest model are slightly improved. As the precision of Random Forest earlier was 0.89 and now it is 0.90 and recall was 0.66 but now it is 0.71.
